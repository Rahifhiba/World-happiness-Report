# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df_15 = pd.read_csv('data/2015.csv')
df_16 = pd.read_csv('data/2016.csv')
df_17 = pd.read_csv('data/2017.csv')
df_18 = pd.read_csv('data/2018.csv')
df_19 = pd.read_csv('data/2019.csv')

# %%
df_15

# %%
print("2015")
print(df_15.isna().sum())
# Out:
# 2015
# Country                          0
# Region                           0
# Happiness Rank                   0
# Happiness Score                  0
# Standard Error                   0
# Economy (GDP per Capita)         0
# Family                           0
# Health (Life Expectancy)         0
# Freedom                          0
# Trust (Government Corruption)    0
# Generosity                       0
# Dystopia Residual                0
# dtype: int64

# %%
print("2015")
print(df_15.info())
# Out:
# 2015
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 158 entries, 0 to 157
# Data columns (total 12 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Country                        158 non-null    object
#  1   Region                         158 non-null    object
#  2   Happiness Rank                 158 non-null    int64
#  3   Happiness Score                158 non-null    float64
#  4   Standard Error                 158 non-null    float64
#  5   Economy (GDP per Capita)       158 non-null    float64
#  6   Family                         158 non-null    float64
#  7   Health (Life Expectancy)       158 non-null    float64
#  8   Freedom                        158 non-null    float64
#  9   Trust (Government Corruption)  158 non-null    float64
#  10  Generosity                     158 non-null    float64
#  11  Dystopia Residual              158 non-null    float64
# ...

# %%
print("2016")
print(df_16.isna().sum())
# Out:
# 2016
# Country                          0
# Region                           0
# Happiness Rank                   0
# Happiness Score                  0
# Lower Confidence Interval        0
# Upper Confidence Interval        0
# Economy (GDP per Capita)         0
# Family                           0
# Health (Life Expectancy)         0
# Freedom                          0
# Trust (Government Corruption)    0
# Generosity                       0
# Dystopia Residual                0
# dtype: int64

# %%
print("2016")
print(df_16.info())
# Out:
# 2016
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 157 entries, 0 to 156
# Data columns (total 13 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Country                        157 non-null    object
#  1   Region                         157 non-null    object
#  2   Happiness Rank                 157 non-null    int64
#  3   Happiness Score                157 non-null    float64
#  4   Lower Confidence Interval      157 non-null    float64
#  5   Upper Confidence Interval      157 non-null    float64
#  6   Economy (GDP per Capita)       157 non-null    float64
#  7   Family                         157 non-null    float64
#  8   Health (Life Expectancy)       157 non-null    float64
#  9   Freedom                        157 non-null    float64
#  10  Trust (Government Corruption)  157 non-null    float64
#  11  Generosity                     157 non-null    float64
# ...

# %%
print("2017")
print(df_17.isna().sum())
# Out:
# 2017
# Country                          0
# Happiness.Rank                   0
# Happiness.Score                  0
# Whisker.high                     0
# Whisker.low                      0
# Economy..GDP.per.Capita.         0
# Family                           0
# Health..Life.Expectancy.         0
# Freedom                          0
# Generosity                       0
# Trust..Government.Corruption.    0
# Dystopia.Residual                0
# dtype: int64

# %%
print("2017")
print(df_17.info())
# Out:
# 2017
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 155 entries, 0 to 154
# Data columns (total 12 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Country                        155 non-null    object
#  1   Happiness.Rank                 155 non-null    int64
#  2   Happiness.Score                155 non-null    float64
#  3   Whisker.high                   155 non-null    float64
#  4   Whisker.low                    155 non-null    float64
#  5   Economy..GDP.per.Capita.       155 non-null    float64
#  6   Family                         155 non-null    float64
#  7   Health..Life.Expectancy.       155 non-null    float64
#  8   Freedom                        155 non-null    float64
#  9   Generosity                     155 non-null    float64
#  10  Trust..Government.Corruption.  155 non-null    float64
#  11  Dystopia.Residual              155 non-null    float64
# ...

# %%
print("2018")
print(df_18.isna().sum())
# Out:
# 2018
# Overall rank                    0
# Country or region               0
# Score                           0
# GDP per capita                  0
# Social support                  0
# Healthy life expectancy         0
# Freedom to make life choices    0
# Generosity                      0
# Perceptions of corruption       1
# dtype: int64

# %%
print("2018")
print(df_18.info())
# Out:
# 2018
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 156 entries, 0 to 155
# Data columns (total 9 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Overall rank                  156 non-null    int64
#  1   Country or region             156 non-null    object
#  2   Score                         156 non-null    float64
#  3   GDP per capita                156 non-null    float64
#  4   Social support                156 non-null    float64
#  5   Healthy life expectancy       156 non-null    float64
#  6   Freedom to make life choices  156 non-null    float64
#  7   Generosity                    156 non-null    float64
#  8   Perceptions of corruption     155 non-null    float64
# dtypes: float64(7), int64(1), object(1)
# memory usage: 11.1+ KB
# None

# %%
print("2019")
print(df_19.isna().sum())
# Out:
# 2019
# Overall rank                    0
# Country or region               0
# Score                           0
# GDP per capita                  0
# Social support                  0
# Healthy life expectancy         0
# Freedom to make life choices    0
# Generosity                      0
# Perceptions of corruption       0
# dtype: int64

# %%
print("2019")
print(df_19.info())
# Out:
# 2019
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 156 entries, 0 to 155
# Data columns (total 9 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Overall rank                  156 non-null    int64
#  1   Country or region             156 non-null    object
#  2   Score                         156 non-null    float64
#  3   GDP per capita                156 non-null    float64
#  4   Social support                156 non-null    float64
#  5   Healthy life expectancy       156 non-null    float64
#  6   Freedom to make life choices  156 non-null    float64
#  7   Generosity                    156 non-null    float64
#  8   Perceptions of corruption     156 non-null    float64
# dtypes: float64(7), int64(1), object(1)
# memory usage: 11.1+ KB
# None

# %% [markdown]
# # What are the factors that contribut in making a country the happiest and the saddest in the world ?

# %%
df_15.columns
# Out:
# Index(['Country', 'Region', 'Happiness Rank', 'Happiness Score',
#        'Standard Error', 'Economy (GDP per Capita)', 'Family',
#        'Health (Life Expectancy)', 'Freedom', 'Trust (Government Corruption)',
#        'Generosity', 'Dystopia Residual'],
#       dtype='object')

# %%
df_16.columns
# Out:
# Index(['Country', 'Region', 'Happiness Rank', 'Happiness Score',
#        'Lower Confidence Interval', 'Upper Confidence Interval',
#        'Economy (GDP per Capita)', 'Family', 'Health (Life Expectancy)',
#        'Freedom', 'Trust (Government Corruption)', 'Generosity',
#        'Dystopia Residual'],
#       dtype='object')

# %% [markdown]
#  [
#     'Country', 'Region', 'Happiness Rank', 'Happiness Score',
#     'Standard Error', 'Economy (GDP per Capita)', 'Family',
#     'Health (Life Expectancy)', 'Freedom', 'Trust (Government Corruption)',
#     'Generosity', 'Dystopia Residual'
# ]

# %%
df_17.columns
# Out:
# Index(['Country', 'Happiness Rank', 'Happiness Score',
#        'Lower Confidence Interval', 'Upper Confidence Interval',
#        'Economy (GDP per Capita)', 'Family', 'Health (Life Expectancy)',
#        'Freedom', 'Generosity', 'Trust (Government Corruption)',
#        'Dystopia Residual', 'Year'],
#       dtype='object')

# %% [markdown]
# ## Let's standarize Datas:

# %%
# rename columns
df_17 = df_17.rename(columns={
        "Happiness.Rank": "Happiness Rank",
        "Happiness.Score": "Happiness Score",
        "Economy..GDP.per.Capita.": "Economy (GDP per Capita)",
        "Health..Life.Expectancy.": "Health (Life Expectancy)",
        "Trust..Government.Corruption.": "Trust (Government Corruption)",
        "Dystopia.Residual": "Dystopia Residual",
        "Whisker.high": "Lower Confidence Interval",
        "Whisker.low": "Upper Confidence Interval",
})


df_18 = df_18.rename(columns={
    "Country or region": "Country",
    "Overall rank": "Happiness Rank",
    "Score": "Happiness Score",
    "GDP per capita": "Economy (GDP per Capita)",
    "Healthy life expectancy": "Health (Life Expectancy)",
    "Freedom to make life choices": "Freedom",
    "Perceptions of corruption": "Trust (Government Corruption)",


})
df_19 = df_19.rename(columns={
    "Country or region": "Country",
    'Overall rank': 'Happiness Rank',
    "Score": "Happiness Score",
    "GDP per capita": "Economy (GDP per Capita)",
    "Healthy life expectancy": "Health (Life Expectancy)",
    "Freedom to make life choices": "Freedom",
    "Perceptions of corruption": "Trust (Government Corruption)",


})
df_18['Trust (Government Corruption)'].fillna(df_18['Trust (Government Corruption)'].mean(), inplace=True)

# %%
# df_15 = df_15.rename(columns={
#     'country': 'Country or region',

# })

df_15['Year'] = 2015
df_16['Year'] = 2016
df_17['Year'] = 2017
df_18['Year'] = 2018
df_19['Year'] = 2019

#  z = 1.96 as 95%
df_15['Lower Confidence Interval'] = df_15['Happiness Score'] - 1.96 * df_15['Standard Error']
df_15['Upper Confidence Interval'] = df_15['Happiness Score'] - 1.96 * df_15['Standard Error']
df_15.drop(['Region'], axis=1, inplace=True)
fraction = 0.05
df_18['Standard Error'] = fraction * df_18['Happiness Score']
df_19['Standard Error'] = fraction * df_19['Happiness Score']

df_18['Lower Confidence Interval'] = df_18['Happiness Score'] - 1.96 * df_18['Standard Error']
df_18['Upper Confidence Interval'] = df_18['Happiness Score'] - 1.96 * df_18['Standard Error']

df_19['Lower Confidence Interval'] = df_19['Happiness Score'] - 1.96 * df_19['Standard Error']
df_19['Upper Confidence Interval'] = df_19['Happiness Score'] - 1.96 * df_19['Standard Error']

df_18['Dystopia Residual'] = 1.85 + df_18['Economy (GDP per Capita)'] + df_18['Social support'] + df_18['Freedom'] + df_18['Generosity'] + df_18['Trust (Government Corruption)'] + df_18['Health (Life Expectancy)']
df_19['Dystopia Residual'] = 1.95 + df_19['Economy (GDP per Capita)'] + df_19['Social support'] + df_19['Freedom'] + df_19['Generosity'] + df_19['Trust (Government Corruption)'] + df_19['Health (Life Expectancy)']

# %% [markdown]
# ## Check correlation before combining dataframes

# %%
def heatmap(df, year):
    """create heatmap for correlation matrix"""
    valid_col = []
    for c in df.columns:
        if not pd.api.types.is_string_dtype(df[c]) and c != 'Year':
            valid_col.append(c)

    plt.figure(figsize=(10, 8))
    sns.heatmap(df[valid_col].corr(), annot=True, cmap='coolwarm', linewidths=0.5, vmin=-1, vmax=1)
    plt.title(f'Correlation matrix for data {year}\n')
    plt.show()

# %%
dfs = [df_15, df_16, df_17, df_18, df_19]
years = [2015, 2016, 2017, 2018, 2019]
fig, axes = plt.subplots(nrows=3, ncols=2, figsize=(20, 20))
axes = axes.flatten()
for i, (df, y) in enumerate(zip(dfs, years)):
    valid_col = [c for c in df.columns if not pd.api.types.is_string_dtype(df[c]) and c != 'Year']
    sns.heatmap(
        df[valid_col].corr(),
        annot=True,
        cmap='coolwarm',
        linewidths=0.5,
        vmin=-1,
        vmax=1,
        ax=axes[i]
    )
    axes[i].set_title(f'Correlation matrix for data {y}\n')
for j in range(len(dfs), len(axes)):
    axes[j].set_visible(False)
plt.tight_layout()
plt.show()


# heatmap_all_years([df_15, df_16, df_17, df_18, df_19])

# %%
# combine all dataframes

df_combined = pd.concat([df_15, df_16, df_17, df_18, df_19], ignore_index=True)

# %%
df_combined.head()
# Out:
#        Country  Happiness Rank  Happiness Score  Standard Error  \
# 0  Switzerland               1            7.587         0.03411
# 1      Iceland               2            7.561         0.04884
# 2      Denmark               3            7.527         0.03328
# 3       Norway               4            7.522         0.03880
# 4       Canada               5            7.427         0.03553
#
#    Economy (GDP per Capita)   Family  Health (Life Expectancy)  Freedom  \
# 0                   1.39651  1.34951                   0.94143  0.66557
# 1                   1.30232  1.40223                   0.94784  0.62877
# 2                   1.32548  1.36058                   0.87464  0.64938
# 3                   1.45900  1.33095                   0.88521  0.66973
# 4                   1.32629  1.32261                   0.90563  0.63297
#
#    Trust (Government Corruption)  Generosity  Dystopia Residual  Year  \
# 0                        0.41978     0.29678            2.51738  2015
# ...

# %%
df_combined.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 782 entries, 0 to 781
# Data columns (total 16 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Country                        782 non-null    object
#  1   Happiness Rank                 782 non-null    int64
#  2   Happiness Score                782 non-null    float64
#  3   Standard Error                 470 non-null    float64
#  4   Economy (GDP per Capita)       782 non-null    float64
#  5   Family                         470 non-null    float64
#  6   Health (Life Expectancy)       782 non-null    float64
#  7   Freedom                        782 non-null    float64
#  8   Trust (Government Corruption)  782 non-null    float64
#  9   Generosity                     782 non-null    float64
#  10  Dystopia Residual              782 non-null    float64
#  11  Year                           782 non-null    int64
# ...

# %%
df_combined.isna().sum()
# Out:
# Country                            0
# Happiness Rank                     0
# Happiness Score                    0
# Standard Error                   312
# Economy (GDP per Capita)           0
# Family                           312
# Health (Life Expectancy)           0
# Freedom                            0
# Trust (Government Corruption)      0
# Generosity                         0
# Dystopia Residual                  0
# Year                               0
# Lower Confidence Interval          0
# Upper Confidence Interval          0
# Region                           625
# Social support                   470
# dtype: int64

# %%
df_tot = df_combined[['Country',
                    'Year',
                    'Happiness Rank',
                    'Happiness Score',
                    'Economy (GDP per Capita)',
                    'Health (Life Expectancy)',
                    'Freedom',
                    'Trust (Government Corruption)',
                    'Lower Confidence Interval',
                    'Upper Confidence Interval',
                    'Generosity',
                    'Dystopia Residual']]

# %%
df_tot.isna().sum()
# Out:
# Country                          0
# Year                             0
# Happiness Rank                   0
# Happiness Score                  0
# Economy (GDP per Capita)         0
# Health (Life Expectancy)         0
# Freedom                          0
# Trust (Government Corruption)    0
# Lower Confidence Interval        0
# Upper Confidence Interval        0
# Generosity                       0
# Dystopia Residual                0
# dtype: int64

# %%
df_tot.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 782 entries, 0 to 781
# Data columns (total 12 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Country                        782 non-null    object
#  1   Year                           782 non-null    int64
#  2   Happiness Rank                 782 non-null    int64
#  3   Happiness Score                782 non-null    float64
#  4   Economy (GDP per Capita)       782 non-null    float64
#  5   Health (Life Expectancy)       782 non-null    float64
#  6   Freedom                        782 non-null    float64
#  7   Trust (Government Corruption)  782 non-null    float64
#  8   Lower Confidence Interval      782 non-null    float64
#  9   Upper Confidence Interval      782 non-null    float64
#  10  Generosity                     782 non-null    float64
#  11  Dystopia Residual              782 non-null    float64
# ...

# %% [markdown]
# Dystopia Residual=Happiness Score−(GDP per Capita+Social Support+Health+Freedom+Trust+Generosity)

# %%
df_tot.head()
# Out:
#        Country  Year  Happiness Rank  Happiness Score  \
# 0  Switzerland  2015               1            7.587
# 1      Iceland  2015               2            7.561
# 2      Denmark  2015               3            7.527
# 3       Norway  2015               4            7.522
# 4       Canada  2015               5            7.427
#
#    Economy (GDP per Capita)  Health (Life Expectancy)  Freedom  \
# 0                   1.39651                   0.94143  0.66557
# 1                   1.30232                   0.94784  0.62877
# 2                   1.32548                   0.87464  0.64938
# 3                   1.45900                   0.88521  0.66973
# 4                   1.32629                   0.90563  0.63297
#
#    Trust (Government Corruption)  Lower Confidence Interval  \
# 0                        0.41978                   7.520144
# 1                        0.14145                   7.465274
# 2                        0.48357                   7.461771
# ...

# %%
df_tot.isna().sum()
# Out:
# Country                          0
# Year                             0
# Happiness Rank                   0
# Happiness Score                  0
# Economy (GDP per Capita)         0
# Health (Life Expectancy)         0
# Freedom                          0
# Trust (Government Corruption)    0
# Lower Confidence Interval        0
# Upper Confidence Interval        0
# Generosity                       0
# Dystopia Residual                0
# dtype: int64

# %%
valid_col = []
for c in df_tot.columns:
    if not pd.api.types.is_object_dtype(df_tot[c]) and c != 'Year':
        valid_col.append(c)
print(valid_col)
plt.figure(figsize=(10, 6))
sns.heatmap(df_tot[valid_col].corr(), annot=True, cmap='coolwarm', linewidths=0.5, vmin=-1, vmax=1)
plt.title(f'Correlation matrix for data 2015-2019\n')
plt.show()
# Out:
# ['Happiness Rank', 'Happiness Score', 'Economy (GDP per Capita)', 'Health (Life Expectancy)', 'Freedom', 'Trust (Government Corruption)', 'Lower Confidence Interval', 'Upper Confidence Interval', 'Generosity', 'Dystopia Residual']

# %%
corr_matrix = df_tot[valid_col].corr()
corr_pairs = corr_matrix.unstack()
corr_pairs = corr_pairs[
        (corr_pairs.index.get_level_values(0) != corr_pairs.index.get_level_values(1)) &
        (corr_pairs.index.get_level_values(0) < corr_pairs.index.get_level_values(1))
    ]
print('Highest correlation pairs:')
print(corr_pairs.sort_values(ascending=False).head(10),"\n")
print("*"*30)
print('\nLowest correlation pairs:')
print(corr_pairs.sort_values(ascending=False).tail(10))
# print(corr_pairs.sort_values(ascending=False))
# Out:
# Highest correlation pairs:
# Lower Confidence Interval  Upper Confidence Interval    0.992791
# Happiness Score            Lower Confidence Interval    0.972320
#                            Upper Confidence Interval    0.972179
# Economy (GDP per Capita)   Happiness Score              0.789284
#                            Health (Life Expectancy)     0.784338
#                            Lower Confidence Interval    0.782625
#                            Upper Confidence Interval    0.779193
# Happiness Score            Health (Life Expectancy)     0.742456
# Health (Life Expectancy)   Upper Confidence Interval    0.684754
#                            Lower Confidence Interval    0.684334
# dtype: float64
#
# ******************************
#
# Lowest correlation pairs:
# Generosity                Happiness Rank                  -0.117713
# Dystopia Residual         Generosity                      -0.211605
#                           Happiness Rank                  -0.286473
# ...

# %% [markdown]
# There is a high correlation between 'Happiness score' and 'lower confidence interval', 'upperconfidence interval', 'Economy (GDP per Capita), 'Health (Life Expectancy)'

# %%
sns.scatterplot(x='Happiness Score', y='Economy (GDP per Capita)', data=df_tot, hue='Year')
# Out:
# <Axes: xlabel='Happiness Score', ylabel='Economy (GDP per Capita)'>

# %%
# export to csv
df_tot.to_csv('data/output.csv', index=False)
